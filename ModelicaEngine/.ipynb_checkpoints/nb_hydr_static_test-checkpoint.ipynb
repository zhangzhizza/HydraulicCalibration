# %%
from ModelicaEngine.ModelicaEngine import Engine
import pandas as pd
import os

# %%
mo_path = '../../MoModels/secondary_pump_test.mo'#'../../MoModels/nb_hydr_static.mo'
fmu_name = mo_path.split(os.sep)[-1].split('.mo')[0]
res_dir = 'secondary_pump_test_res'#'./nb_hydr_static_res'
sudo_pwd = '63z64q92zza'

# %% [markdown]
# ### Adjust model "parameter"

# %%
mo_engine = Engine(mo_path, res_dir, sudo_pwd, 
							log_level = 'INFO',
                            set_params = [['parameter', 'Real', 'chr_pipe_len', '100'],
                                          ['parameter', 'Real', 'chr_flow_nom', '100']])
sim_res_dir = mo_engine.simulate(start_time=0, final_time=3600,
					res_names = ['chw_ret_P.p', 'chw_sup_P.p',
								 'chw_sup_m.m_flow', 'chiller_1.port_a.p',
                                 'chiller_1.port_b.p'])
res_pd = pd.read_csv('{}{}{}_res.csv'.format(sim_res_dir, os.sep, fmu_name))
# Out:
# [2022-07-07 21:58:21,254] ModelicaEngine-nb_hydr_static INFO:Compilation starts
# Compilation INFO:Preparing compilation model directory...
# Compilation INFO:Setting specified parameters...
# Compilation INFO:Calling compilation script...
# Compilation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts//tmpcomp_nb_hydr_static_1657202301
#
# Compilation INFO:Compiler arguments:
#
# Compilation INFO:  -log=info,w|xml|stderr -opt=nle_solver_tol_factor:0.01,generate_html_diagnostics:false -target=me -version=2.0 -platform=linux64 -out=. -modelicapath=/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts//tmpcomp_nb_hydr_static_1657202301:/usr/local/JModelica/ThirdParty/MSL  nb_hydr_static
#
# Compilation INFO:Current working directory:
#
# Compilation INFO:  /mnt/shared/JMDcokerScripts/tmpcomp_nb_hydr_static_1657202301
#
# Compilation INFO:Compiler version: unknown
#
# Compilation INFO:Java version: 11.0.4
#
# Compilation INFO:OS name: Linux
#
# Compilation INFO:OS architecture: amd64
#
# Compilation INFO:MODELICAPATH    = /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts//tmpcomp_nb_hydr_static_1657202301:/usr/local/JModelica/ThirdParty/MSL
#
# Compilation INFO:JAVA_HOME       = /usr/lib/jvm/java-11-openjdk-amd64
#
# Compilation INFO:JMODELICA_HOME  = /usr/local/JModelica/bin/..
#
# Compilation INFO:======= Compiling model =======
#
# Compilation INFO:Checking for errors...
#
# Compilation INFO:MODELICAPATH = /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts//tmpcomp_nb_hydr_static_1657202301:/usr/local/JModelica/ThirdParty/MSL
#
# Compilation INFO:extra_lib_dirs =
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpcomp_nb_hydr_static_1657202301/nb_hydr_static.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/Boundary_pT.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Icons.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/BaseClasses/PartialSource_Xi_C.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/BaseClasses/PartialSource.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/SpeedControlled_y.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/PartialFlowMachine.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/LumpedVolumeDeclarations.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/PartialTwoPortInterface.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/PartialTwoPort.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/Pipe.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/BaseClasses/Pipe.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/TwoPortFlowResistanceParameters.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/Junction.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/PartialThreeWayResistance.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/MassFlowRate.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Sources.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Interfaces.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Icons.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/Pressure.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/PressureDrop.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/PartialResistance.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Media/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Media/Water.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Media/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Media/Water/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/SIunits.mo...
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Interfaces.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Types.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Constants.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/ModelicaServices/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Utilities.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Utilities/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Utilities/Streams.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Math.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/Pumps/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/Pumps/Wilo/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/Pumps/Wilo/CronolineIL80slash220dash4slash4.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/Generic.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Types.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Types.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Types.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Routing.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Delays/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Delays/DelayFirstOrder.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/MixingVolume.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/BaseClasses/PartialMixingVolume.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/IdealSource.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/PartialTwoPortTransport.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/PowerInterface.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/RelativePressure.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/FlowMachineInterface.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/flowParameters.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/efficiencyParameters.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/powerParameters.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/flowParametersInternal.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/splineDerivatives.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/isMonotonic.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Math/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Math/BooleanVectors.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/pressure.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/cubicHermiteLinearExtrapolation.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/power.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/smoothMax.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/regStep.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/efficiency.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Vessels.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/StaticTwoPortConservationEquation.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/ConservationEquation.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/HeatTransfer/package.mo...
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/HeatTransfer/Sources/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/HeatTransfer/Sources/PrescribedTemperature.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Utilities/Strings.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/inverseXRegularized.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/smoothTransition.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/der_smoothTransition.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/der_2_smoothTransition.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/der_inverseXRegularized.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/BaseClasses/PartialFlowSensor.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/BaseClasses/MixingVolumeHeatPort.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Pipes.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_dp.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_m_flow.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_dp_der.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_dp_der2.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_m_flow_der.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_m_flow_der2.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/BaseClasses/PartialAbsoluteSensor.mo...
#
# Compilation INFO:Warning at line 50, column 12, in file '/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/BaseClasses/PartialSource.mo', DEPRECATED_CARDINALITY,
#
# Compilation INFO:In components:
#
# Compilation INFO:    chw_ret
#
# Compilation INFO:    chw_sup
#
# Compilation INFO:  The cardinality() function-like operator is deprecated, and will be removed in a future version of Modelica
#
# Compilation INFO:Warning at line 1775, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.c0 does not have a binding expression
#
# Compilation INFO:Warning at line 1775, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
#
# Compilation INFO:  The parameter chwp_2.filter.c0 does not have a binding expression
#
# Compilation INFO:Warning at line 1775, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.c0 does not have a binding expression
#
# Compilation INFO:Warning at line 1775, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.c0 does not have a binding expression
#
# Compilation INFO:Warning at line 1776, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.c1 does not have a binding expression
#
# Compilation INFO:Warning at line 1776, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
#
# Compilation INFO:  The parameter chwp_2.filter.c1 does not have a binding expression
#
# Compilation INFO:Warning at line 1776, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.c1 does not have a binding expression
#
# Compilation INFO:Warning at line 1776, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.c1 does not have a binding expression
#
# Compilation INFO:Warning at line 1780, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.a does not have a binding expression
#
# Compilation INFO:Warning at line 1780, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
#
# Compilation INFO:  The parameter chwp_2.filter.a does not have a binding expression
#
# Compilation INFO:Warning at line 1780, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.a does not have a binding expression
#
# Compilation INFO:Warning at line 1780, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.a does not have a binding expression
#
# Compilation INFO:Warning at line 1781, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.b does not have a binding expression
#
# Compilation INFO:Warning at line 1781, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
# Compilation INFO:  The parameter chwp_2.filter.b does not have a binding expression
#
# Compilation INFO:Warning at line 1781, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.b does not have a binding expression
#
# Compilation INFO:Warning at line 1781, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.b does not have a binding expression
#
# Compilation INFO:Warning at line 1782, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.ku does not have a binding expression
#
# Compilation INFO:Warning at line 1782, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
#
# Compilation INFO:  The parameter chwp_2.filter.ku does not have a binding expression
#
# Compilation INFO:Warning at line 1782, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.ku does not have a binding expression
#
# Compilation INFO:Warning at line 1782, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.ku does not have a binding expression
#
# Compilation INFO:Warning at line 1783, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.k1 does not have a binding expression
#
# Compilation INFO:Warning at line 1783, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
#
# Compilation INFO:  The parameter chwp_2.filter.k1 does not have a binding expression
#
# Compilation INFO:Warning at line 1783, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.k1 does not have a binding expression
#
# Compilation INFO:Warning at line 1783, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.k1 does not have a binding expression
#
# Compilation INFO:Warning at line 1785, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.k2 does not have a binding expression
#
# Compilation INFO:Warning at line 1785, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
#
# Compilation INFO:  The parameter chwp_2.filter.k2 does not have a binding expression
#
# Compilation INFO:Warning at line 1785, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.k2 does not have a binding expression
#
# Compilation INFO:Warning at line 1785, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.k2 does not have a binding expression
#
# Compilation INFO:Flattening model...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Utilities/Types.mo...
#
# Compilation INFO:Applying transformation: enableIfEquationElimination...
#
# Compilation INFO:Applying transformation: genInitArrayStatements...
#
# Compilation INFO:Applying transformation: scalarize...
#
# Compilation INFO:Applying transformation: MakeReinitedVarsStates...
#
# Compilation INFO:Applying transformation: enableIfEquationElimination...
#
# Compilation INFO:Applying transformation: enableStreamsRewrite...
#
# Compilation INFO:Applying transformation: ExtractEventGeneratingExpressions...
#
# Compilation INFO:Applying transformation: GenerateEventIndicators...
#
# Compilation INFO:Applying transformation: convertWhenToIf...
#
# Compilation INFO:Applying transformation: FunctionInliningIfSet...
#
# Compilation INFO:Applying transformation: setFDerivativeVariables...
#
# Compilation INFO:Applying transformation: addFPreVariables...
#
# Compilation INFO:Applying transformation: enableIfEquationRewrite...
#
# Compilation INFO:Applying transformation: aliasEliminationIfSet...
#
# Compilation INFO:Applying transformation: variabilityPropagationIfSet...
#
# Compilation INFO:Applying transformation: aliasEliminationIfSet...
#
# Compilation INFO:Applying transformation: eliminateLinearEquations...
#
# Compilation INFO:Applying transformation: aliasEliminationIfSet...
#
# Compilation INFO:Applying transformation: enableExpandedInStreamRewrite...
#
# Compilation INFO:Applying transformation: evaluateAsserts...
#
# Compilation INFO:Applying transformation: enableSemiLinearRewrite...
#
# Compilation INFO:Applying transformation: eliminateEqualSwitches...
#
# Compilation INFO:Applying transformation: genInitialEquations...
#
# Compilation INFO:Applying transformation: setFDerivativeVariablesPreBLT...
#
# Compilation INFO:Applying transformation: indexReduction...
#
# Compilation INFO:Applying transformation: LateFunctionInliningIfSet...
#
# Compilation INFO:Applying transformation: commonSubexpressionEliminationIfSet...
#
# Compilation INFO:Applying transformation: addFPreVariables...
#
# Compilation INFO:Applying transformation: aliasEliminationIfSet...
#
# Compilation INFO:Applying transformation: eliminateLinearEquations...
#
# Compilation INFO:Applying transformation: sortDependentParameters...
#
# Compilation INFO:Applying transformation: addRuntimeOptionParameters...
#
# Compilation INFO:Applying transformation: computeMatchingsAndBLT...
#
# Compilation INFO:Warning at line 1757, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo':
#
# Compilation INFO:  Iteration variable "chwp_1.filter.x[1]" is missing start value!
#
# Compilation INFO:Warning at line 1757, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo':
#
# Compilation INFO:  Iteration variable "chwp_2.filter.x[1]" is missing start value!
#
# Compilation INFO:Warning at line 1757, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo':
#
# Compilation INFO:  Iteration variable "chwp_3.filter.x[1]" is missing start value!
#
# Compilation INFO:Warning at line 1757, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo':
#
# Compilation INFO:  Iteration variable "chwp_4.filter.x[1]" is missing start value!
#
# Compilation INFO:Generating code...
#
# Compilation INFO:====== Model compiled successfully =======
#
# Compilation INFO:
#
# Compilation INFO:Compilation_Result_Directory:fmus/nb_hydr_static_v1
#
# Compilation INFO:Compilation script compeltes
# Compilation ERROR:[sudo] password for zhiangz:
# Compilation INFO:Compilaton succeeded, compiled FMU is ready at: ./nb_hydr_static_res/compilation/nb_hydr_static.fmu
# Simulation INFO:Preparing simulation model directory...
# Simulation INFO:Calling simulation script...
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_nb_hydr_static_1657202374
# ./nb_hydr_static_res/compilation/nb_hydr_static.fmu ./nb_hydr_static_res/compilation/nb_hydr_static.mo
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 254
#
# Simulation INFO: Number of function evaluations                  : 300
#
# Simulation INFO: Number of Jacobian evaluations                  : 5
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 7
#
# Simulation INFO: Number of nonlinear iterations                  : 296
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 255
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.298448085785 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/nb_hydr_static_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation INFO:Simulation succeeded, results are ready at: ./nb_hydr_static_res/simres_run2

# %%
res_pd
# Out:
#              time  chw_ret_P.p  chiller_1.port_a.p  chiller_1.port_b.p  \
# 0    0.000000e+00     400000.0       391908.922629       391684.388067
# 1    4.112140e-09     400000.0       391908.922629       391684.388067
# 2    4.112552e-05     400000.0       391908.922695       391684.388133
# 3    4.523396e-04     400000.0       391908.930652       391684.396072
# 4    8.635536e-04     400000.0       391908.951869       391684.417237
# ..            ...          ...                 ...                 ...
# 250  2.840740e+03     400000.0       975158.939414       973516.046611
# 251  3.030460e+03     400000.0       975158.939414       973516.046611
# 252  3.220181e+03     400000.0       975158.939414       973516.046611
# 253  3.409902e+03     400000.0       975158.939414       973516.046611
# 254  3.600000e+03     400000.0       975158.939414       973516.046611
#
#        chw_sup_P.p  chw_sup_m.m_flow
# 0    364173.759774        400.542631
# 1    364173.759774        400.542631
# 2    364173.759820        400.542631
# 3    364173.765377        400.542649
# 4    364173.780195        400.542695
# ..             ...               ...
# 250  771442.681507       1085.636543
# 251  771442.681507       1085.636543
# 252  771442.681507       1085.636543
# 253  771442.681507       1085.636543
# 254  771442.681507       1085.636543
#
# [255 rows x 6 columns]

# %% [markdown]
# ### Adjust component parameters

# %%
mo_engine = Engine(mo_path, res_dir, sudo_pwd, 
							log_level = 'INFO',
                            set_params = [['parameter', 'Real', 'chr_pipe_len', '100'],
                                          ['parameter', 'Real', 'chr_flow_nom', '100'],
    ['Buildings.Fluid.FixedResistances.Junction', 'jun_4', {'m_flow_nominal':'{111,55,-180}',
                                                           'dp_nominal':'{5000,6000,-5000}'}]])
sim_res_dir = mo_engine.simulate(start_time=0, final_time=3600,
					res_names = ['chw_ret_P.p', 'chw_sup_P.p',
								 'chw_sup_m.m_flow', 'chiller_1.port_a.p',
                                 'chiller_1.port_b.p'])
res_pd = pd.read_csv('{}{}{}_res.csv'.format(sim_res_dir, os.sep, fmu_name))
# Out:
# [2022-07-07 21:59:58,838] ModelicaEngine-nb_hydr_static INFO:Compilation starts
# Compilation INFO:Preparing compilation model directory...
# Compilation INFO:Setting specified parameters...
# Compilation INFO:Calling compilation script...
# Compilation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts//tmpcomp_nb_hydr_static_1657202398
#
# Compilation INFO:Compiler arguments:
#
# Compilation INFO:  -log=info,w|xml|stderr -opt=nle_solver_tol_factor:0.01,generate_html_diagnostics:false -target=me -version=2.0 -platform=linux64 -out=. -modelicapath=/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts//tmpcomp_nb_hydr_static_1657202398:/usr/local/JModelica/ThirdParty/MSL  nb_hydr_static
#
# Compilation INFO:Current working directory:
#
# Compilation INFO:  /mnt/shared/JMDcokerScripts/tmpcomp_nb_hydr_static_1657202398
#
# Compilation INFO:Compiler version: unknown
#
# Compilation INFO:Java version: 11.0.4
#
# Compilation INFO:OS name: Linux
#
# Compilation INFO:OS architecture: amd64
#
# Compilation INFO:MODELICAPATH    = /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts//tmpcomp_nb_hydr_static_1657202398:/usr/local/JModelica/ThirdParty/MSL
#
# Compilation INFO:JAVA_HOME       = /usr/lib/jvm/java-11-openjdk-amd64
#
# Compilation INFO:JMODELICA_HOME  = /usr/local/JModelica/bin/..
#
# Compilation INFO:======= Compiling model =======
#
# Compilation INFO:Checking for errors...
#
# Compilation INFO:MODELICAPATH = /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts//tmpcomp_nb_hydr_static_1657202398:/usr/local/JModelica/ThirdParty/MSL
#
# Compilation INFO:extra_lib_dirs =
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpcomp_nb_hydr_static_1657202398/nb_hydr_static.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/Boundary_pT.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Icons.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/BaseClasses/PartialSource_Xi_C.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/BaseClasses/PartialSource.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/SpeedControlled_y.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/PartialFlowMachine.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/LumpedVolumeDeclarations.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/PartialTwoPortInterface.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/PartialTwoPort.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/Pipe.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/BaseClasses/Pipe.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/TwoPortFlowResistanceParameters.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/Junction.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/PartialThreeWayResistance.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/MassFlowRate.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Sources.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Interfaces.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Icons.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/Pressure.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/PressureDrop.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/PartialResistance.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Media/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Media/Water.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Media/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Media/Water/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/SIunits.mo...
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Interfaces.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Types.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Constants.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/ModelicaServices/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Utilities.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Utilities/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Utilities/Streams.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Math.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/Pumps/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/Pumps/Wilo/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/Pumps/Wilo/CronolineIL80slash220dash4slash4.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/Generic.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Types.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Types.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Types.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Routing.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Delays/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Delays/DelayFirstOrder.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/MixingVolume.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/BaseClasses/PartialMixingVolume.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/IdealSource.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/PartialTwoPortTransport.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/PowerInterface.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/RelativePressure.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/FlowMachineInterface.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/flowParameters.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/efficiencyParameters.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/powerParameters.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/flowParametersInternal.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/splineDerivatives.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/isMonotonic.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Math/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Math/BooleanVectors.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/pressure.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/cubicHermiteLinearExtrapolation.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/power.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/smoothMax.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/regStep.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/efficiency.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Vessels.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/StaticTwoPortConservationEquation.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/ConservationEquation.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/HeatTransfer/package.mo...
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/HeatTransfer/Sources/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/HeatTransfer/Sources/PrescribedTemperature.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Utilities/Strings.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/inverseXRegularized.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/smoothTransition.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/der_smoothTransition.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/der_2_smoothTransition.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/der_inverseXRegularized.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/BaseClasses/PartialFlowSensor.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/BaseClasses/MixingVolumeHeatPort.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Pipes.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_dp.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_m_flow.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_dp_der.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_dp_der2.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_m_flow_der.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_m_flow_der2.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/BaseClasses/PartialAbsoluteSensor.mo...
#
# Compilation INFO:Warning at line 50, column 12, in file '/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/BaseClasses/PartialSource.mo', DEPRECATED_CARDINALITY,
#
# Compilation INFO:In components:
#
# Compilation INFO:    chw_ret
#
# Compilation INFO:    chw_sup
#
# Compilation INFO:  The cardinality() function-like operator is deprecated, and will be removed in a future version of Modelica
#
# Compilation INFO:Warning at line 1775, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.c0 does not have a binding expression
#
# Compilation INFO:Warning at line 1775, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
#
# Compilation INFO:  The parameter chwp_2.filter.c0 does not have a binding expression
#
# Compilation INFO:Warning at line 1775, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.c0 does not have a binding expression
#
# Compilation INFO:Warning at line 1775, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.c0 does not have a binding expression
#
# Compilation INFO:Warning at line 1776, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.c1 does not have a binding expression
#
# Compilation INFO:Warning at line 1776, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
#
# Compilation INFO:  The parameter chwp_2.filter.c1 does not have a binding expression
#
# Compilation INFO:Warning at line 1776, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.c1 does not have a binding expression
#
# Compilation INFO:Warning at line 1776, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.c1 does not have a binding expression
#
# Compilation INFO:Warning at line 1780, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.a does not have a binding expression
#
# Compilation INFO:Warning at line 1780, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
#
# Compilation INFO:  The parameter chwp_2.filter.a does not have a binding expression
#
# Compilation INFO:Warning at line 1780, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.a does not have a binding expression
#
# Compilation INFO:Warning at line 1780, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.a does not have a binding expression
#
# Compilation INFO:Warning at line 1781, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.b does not have a binding expression
#
# Compilation INFO:Warning at line 1781, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
# Compilation INFO:  The parameter chwp_2.filter.b does not have a binding expression
#
# Compilation INFO:Warning at line 1781, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.b does not have a binding expression
#
# Compilation INFO:Warning at line 1781, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.b does not have a binding expression
#
# Compilation INFO:Warning at line 1782, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.ku does not have a binding expression
#
# Compilation INFO:Warning at line 1782, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
#
# Compilation INFO:  The parameter chwp_2.filter.ku does not have a binding expression
#
# Compilation INFO:Warning at line 1782, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.ku does not have a binding expression
#
# Compilation INFO:Warning at line 1782, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.ku does not have a binding expression
#
# Compilation INFO:Warning at line 1783, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.k1 does not have a binding expression
#
# Compilation INFO:Warning at line 1783, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
#
# Compilation INFO:  The parameter chwp_2.filter.k1 does not have a binding expression
#
# Compilation INFO:Warning at line 1783, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.k1 does not have a binding expression
#
# Compilation INFO:Warning at line 1783, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.k1 does not have a binding expression
#
# Compilation INFO:Warning at line 1785, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.k2 does not have a binding expression
#
# Compilation INFO:Warning at line 1785, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
#
# Compilation INFO:  The parameter chwp_2.filter.k2 does not have a binding expression
#
# Compilation INFO:Warning at line 1785, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.k2 does not have a binding expression
#
# Compilation INFO:Warning at line 1785, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.k2 does not have a binding expression
#
# Compilation INFO:Flattening model...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Utilities/Types.mo...
#
# Compilation INFO:Applying transformation: enableIfEquationElimination...
#
# Compilation INFO:Applying transformation: genInitArrayStatements...
#
# Compilation INFO:Applying transformation: scalarize...
#
# Compilation INFO:Applying transformation: MakeReinitedVarsStates...
#
# Compilation INFO:Applying transformation: enableIfEquationElimination...
#
# Compilation INFO:Applying transformation: enableStreamsRewrite...
#
# Compilation INFO:Applying transformation: ExtractEventGeneratingExpressions...
#
# Compilation INFO:Applying transformation: GenerateEventIndicators...
#
# Compilation INFO:Applying transformation: convertWhenToIf...
#
# Compilation INFO:Applying transformation: FunctionInliningIfSet...
#
# Compilation INFO:Applying transformation: setFDerivativeVariables...
#
# Compilation INFO:Applying transformation: addFPreVariables...
#
# Compilation INFO:Applying transformation: enableIfEquationRewrite...
#
# Compilation INFO:Applying transformation: aliasEliminationIfSet...
#
# Compilation INFO:Applying transformation: variabilityPropagationIfSet...
#
# Compilation INFO:Applying transformation: aliasEliminationIfSet...
#
# Compilation INFO:Applying transformation: eliminateLinearEquations...
#
# Compilation INFO:Applying transformation: aliasEliminationIfSet...
#
# Compilation INFO:Applying transformation: enableExpandedInStreamRewrite...
#
# Compilation INFO:Applying transformation: evaluateAsserts...
#
# Compilation INFO:Applying transformation: enableSemiLinearRewrite...
#
# Compilation INFO:Applying transformation: eliminateEqualSwitches...
#
# Compilation INFO:Applying transformation: genInitialEquations...
#
# Compilation INFO:Applying transformation: setFDerivativeVariablesPreBLT...
#
# Compilation INFO:Applying transformation: indexReduction...
#
# Compilation INFO:Applying transformation: LateFunctionInliningIfSet...
#
# Compilation INFO:Applying transformation: commonSubexpressionEliminationIfSet...
#
# Compilation INFO:Applying transformation: addFPreVariables...
#
# Compilation INFO:Applying transformation: aliasEliminationIfSet...
#
# Compilation INFO:Applying transformation: eliminateLinearEquations...
#
# Compilation INFO:Applying transformation: sortDependentParameters...
#
# Compilation INFO:Applying transformation: addRuntimeOptionParameters...
#
# Compilation INFO:Applying transformation: computeMatchingsAndBLT...
#
# Compilation INFO:Warning at line 1757, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo':
#
# Compilation INFO:  Iteration variable "chwp_1.filter.x[1]" is missing start value!
#
# Compilation INFO:Warning at line 1757, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo':
#
# Compilation INFO:  Iteration variable "chwp_2.filter.x[1]" is missing start value!
#
# Compilation INFO:Warning at line 1757, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo':
#
# Compilation INFO:  Iteration variable "chwp_3.filter.x[1]" is missing start value!
#
# Compilation INFO:Warning at line 1757, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo':
#
# Compilation INFO:  Iteration variable "chwp_4.filter.x[1]" is missing start value!
#
# Compilation INFO:Generating code...
#
# Compilation INFO:====== Model compiled successfully =======
#
# Compilation INFO:
#
# Compilation INFO:Compilation_Result_Directory:fmus/nb_hydr_static_v1
#
# Compilation INFO:Compilation script compeltes
# Compilation ERROR:[sudo] password for zhiangz:
# Compilation INFO:Compilaton succeeded, compiled FMU is ready at: ./nb_hydr_static_res/compilation/nb_hydr_static.fmu
# Simulation INFO:Preparing simulation model directory...
# Simulation INFO:Calling simulation script...
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_nb_hydr_static_1657202447
# ./nb_hydr_static_res/compilation/nb_hydr_static.fmu ./nb_hydr_static_res/compilation/nb_hydr_static.mo
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 254
#
# Simulation INFO: Number of function evaluations                  : 291
#
# Simulation INFO: Number of Jacobian evaluations                  : 5
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 4
#
# Simulation INFO: Number of nonlinear iterations                  : 287
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 255
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.201153039932 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/nb_hydr_static_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation INFO:Simulation succeeded, results are ready at: ./nb_hydr_static_res/simres_run3

# %%
res_pd
# Out:
#              time  chw_ret_P.p  chiller_1.port_a.p  chiller_1.port_b.p  \
# 0    0.000000e+00     400000.0        3.978202e+05        3.977593e+05
# 1    4.112140e-09     400000.0        3.978202e+05        3.977593e+05
# 2    4.112552e-05     400000.0        3.978202e+05        3.977593e+05
# 3    4.523396e-04     400000.0        3.978202e+05        3.977593e+05
# 4    8.635536e-04     400000.0        3.978202e+05        3.977593e+05
# ..            ...          ...                 ...                 ...
# 250  3.292599e+03     400000.0        1.018774e+06        1.018335e+06
# 251  3.381244e+03     400000.0        1.018774e+06        1.018335e+06
# 252  3.469888e+03     400000.0        1.018774e+06        1.018335e+06
# 253  3.558532e+03     400000.0        1.018774e+06        1.018335e+06
# 254  3.600000e+03     400000.0        1.018774e+06        1.018335e+06
#
#        chw_sup_P.p  chw_sup_m.m_flow
# 0    316021.852803        200.136533
# 1    316021.852803        200.136533
# 2    316021.852815        200.136533
# 3    316021.854204        200.136542
# 4    316021.857910        200.136565
# ..             ...               ...
# 250  417782.157715        542.637443
# 251  417782.157715        542.637443
# 252  417782.157715        542.637443
# 253  417782.157715        542.637443
# 254  417782.157715        542.637443
#
# [255 rows x 6 columns]

# %%
mo_engine = Engine(mo_path, res_dir, sudo_pwd, 
							log_level = 'DEBUG',
                            set_params = \
                               [['parameter', 'Real', 'chr_pipe_len', '20']])
sim_res_dir = mo_engine.simulate(start_time=0, final_time=3600,
					res_names = ['chw_ret_P.p', 'chw_sup_P.p',
								 'chw_sup_m.m_flow', 'chiller_1.port_a.p',
                                 'chiller_1.port_b.p'])
res_pd = pd.read_csv('{}{}{}_res.csv'.format(sim_res_dir, os.sep, fmu_name))
# Out:
# [2022-07-07 22:02:57,637] ModelicaEngine-nb_hydr_static INFO:Compilation starts
# Compilation INFO:Preparing compilation model directory...
# Compilation DEBUG:Compilation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpcomp_nb_hydr_static_1657202577
# Compilation DEBUG:docker_mo_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpcomp_nb_hydr_static_1657202577/nb_hydr_static.mo
# Compilation DEBUG:docker_mo_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpcomp_nb_hydr_static_1657202577
# Compilation INFO:Setting specified parameters...
# Compilation INFO:Calling compilation script...
# Compilation DEBUG:Compilation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh /tmpcomp_nb_hydr_static_1657202577 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/compile_fmu_1.py nb_hydr_static /tmpcomp_nb_hydr_static_1657202577 me False
# Compilation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts//tmpcomp_nb_hydr_static_1657202577
#
# Compilation INFO:Compiler arguments:
#
# Compilation INFO:  -log=info,w|xml|stderr -opt=nle_solver_tol_factor:0.01,generate_html_diagnostics:false -target=me -version=2.0 -platform=linux64 -out=. -modelicapath=/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts//tmpcomp_nb_hydr_static_1657202577:/usr/local/JModelica/ThirdParty/MSL  nb_hydr_static
#
# Compilation INFO:Current working directory:
#
# Compilation INFO:  /mnt/shared/JMDcokerScripts/tmpcomp_nb_hydr_static_1657202577
#
# Compilation INFO:Compiler version: unknown
#
# Compilation INFO:Java version: 11.0.4
#
# Compilation INFO:OS name: Linux
#
# Compilation INFO:OS architecture: amd64
#
# Compilation INFO:MODELICAPATH    = /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts//tmpcomp_nb_hydr_static_1657202577:/usr/local/JModelica/ThirdParty/MSL
#
# Compilation INFO:JAVA_HOME       = /usr/lib/jvm/java-11-openjdk-amd64
#
# Compilation INFO:JMODELICA_HOME  = /usr/local/JModelica/bin/..
#
# Compilation INFO:======= Compiling model =======
#
# Compilation INFO:Checking for errors...
#
# Compilation INFO:MODELICAPATH = /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts//tmpcomp_nb_hydr_static_1657202577:/usr/local/JModelica/ThirdParty/MSL
#
# Compilation INFO:extra_lib_dirs =
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpcomp_nb_hydr_static_1657202577/nb_hydr_static.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/Boundary_pT.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Icons.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/BaseClasses/PartialSource_Xi_C.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/BaseClasses/PartialSource.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/SpeedControlled_y.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/PartialFlowMachine.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/LumpedVolumeDeclarations.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/PartialTwoPortInterface.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/PartialTwoPort.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/Pipe.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/BaseClasses/Pipe.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/TwoPortFlowResistanceParameters.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/Junction.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/PartialThreeWayResistance.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/MassFlowRate.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Sources.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Interfaces.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Icons.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/Pressure.mo...
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/PressureDrop.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/PartialResistance.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Media/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Media/Water.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Media/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Media/Water/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/SIunits.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Interfaces.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Types.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Constants.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/ModelicaServices/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Utilities.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Utilities/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Utilities/Streams.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Math.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/Pumps/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/Pumps/Wilo/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/Pumps/Wilo/CronolineIL80slash220dash4slash4.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/Generic.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Types.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Types.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Types.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Routing.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Delays/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Delays/DelayFirstOrder.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/MixingVolume.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/BaseClasses/PartialMixingVolume.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/IdealSource.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/PartialTwoPortTransport.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/PowerInterface.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/RelativePressure.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/FlowMachineInterface.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/flowParameters.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/efficiencyParameters.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/powerParameters.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/flowParametersInternal.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/splineDerivatives.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/isMonotonic.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Math/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Math/BooleanVectors.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/pressure.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/cubicHermiteLinearExtrapolation.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/power.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/smoothMax.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/regStep.mo...
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/efficiency.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Vessels.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/StaticTwoPortConservationEquation.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/ConservationEquation.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/HeatTransfer/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/HeatTransfer/Sources/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/HeatTransfer/Sources/PrescribedTemperature.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Utilities/Strings.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/inverseXRegularized.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/smoothTransition.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/der_smoothTransition.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/der_2_smoothTransition.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/der_inverseXRegularized.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/BaseClasses/PartialFlowSensor.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/BaseClasses/MixingVolumeHeatPort.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Pipes.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_dp.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_m_flow.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_dp_der.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_dp_der2.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_m_flow_der.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_m_flow_der2.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/BaseClasses/PartialAbsoluteSensor.mo...
#
# Compilation INFO:Warning at line 50, column 12, in file '/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/BaseClasses/PartialSource.mo', DEPRECATED_CARDINALITY,
#
# Compilation INFO:In components:
#
# Compilation INFO:    chw_ret
#
# Compilation INFO:    chw_sup
#
# Compilation INFO:  The cardinality() function-like operator is deprecated, and will be removed in a future version of Modelica
#
# Compilation INFO:Warning at line 1775, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.c0 does not have a binding expression
#
# Compilation INFO:Warning at line 1775, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
#
# Compilation INFO:  The parameter chwp_2.filter.c0 does not have a binding expression
#
# Compilation INFO:Warning at line 1775, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.c0 does not have a binding expression
#
# Compilation INFO:Warning at line 1775, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.c0 does not have a binding expression
#
# Compilation INFO:Warning at line 1776, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.c1 does not have a binding expression
#
# Compilation INFO:Warning at line 1776, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
#
# Compilation INFO:  The parameter chwp_2.filter.c1 does not have a binding expression
#
# Compilation INFO:Warning at line 1776, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.c1 does not have a binding expression
#
# Compilation INFO:Warning at line 1776, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.c1 does not have a binding expression
#
# Compilation INFO:Warning at line 1780, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.a does not have a binding expression
#
# Compilation INFO:Warning at line 1780, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
#
# Compilation INFO:  The parameter chwp_2.filter.a does not have a binding expression
#
# Compilation INFO:Warning at line 1780, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.a does not have a binding expression
# Compilation INFO:Warning at line 1780, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.a does not have a binding expression
#
# Compilation INFO:Warning at line 1781, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.b does not have a binding expression
#
# Compilation INFO:Warning at line 1781, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
#
# Compilation INFO:  The parameter chwp_2.filter.b does not have a binding expression
#
# Compilation INFO:Warning at line 1781, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.b does not have a binding expression
#
# Compilation INFO:Warning at line 1781, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.b does not have a binding expression
#
# Compilation INFO:Warning at line 1782, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.ku does not have a binding expression
#
# Compilation INFO:Warning at line 1782, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
#
# Compilation INFO:  The parameter chwp_2.filter.ku does not have a binding expression
#
# Compilation INFO:Warning at line 1782, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.ku does not have a binding expression
#
# Compilation INFO:Warning at line 1782, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.ku does not have a binding expression
#
# Compilation INFO:Warning at line 1783, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.k1 does not have a binding expression
#
# Compilation INFO:Warning at line 1783, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
#
# Compilation INFO:  The parameter chwp_2.filter.k1 does not have a binding expression
#
# Compilation INFO:Warning at line 1783, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.k1 does not have a binding expression
#
# Compilation INFO:Warning at line 1783, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.k1 does not have a binding expression
#
# Compilation INFO:Warning at line 1785, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.k2 does not have a binding expression
#
# Compilation INFO:Warning at line 1785, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_2:
#
# Compilation INFO:  The parameter chwp_2.filter.k2 does not have a binding expression
#
# Compilation INFO:Warning at line 1785, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_3:
#
# Compilation INFO:  The parameter chwp_3.filter.k2 does not have a binding expression
#
# Compilation INFO:Warning at line 1785, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_4:
#
# Compilation INFO:  The parameter chwp_4.filter.k2 does not have a binding expression
#
# Compilation INFO:Flattening model...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Utilities/Types.mo...
#
# Compilation INFO:Applying transformation: enableIfEquationElimination...
#
# Compilation INFO:Applying transformation: genInitArrayStatements...
#
# Compilation INFO:Applying transformation: scalarize...
#
# Compilation INFO:Applying transformation: MakeReinitedVarsStates...
#
# Compilation INFO:Applying transformation: enableIfEquationElimination...
#
# Compilation INFO:Applying transformation: enableStreamsRewrite...
#
# Compilation INFO:Applying transformation: ExtractEventGeneratingExpressions...
#
# Compilation INFO:Applying transformation: GenerateEventIndicators...
#
# Compilation INFO:Applying transformation: convertWhenToIf...
#
# Compilation INFO:Applying transformation: FunctionInliningIfSet...
#
# Compilation INFO:Applying transformation: setFDerivativeVariables...
#
# Compilation INFO:Applying transformation: addFPreVariables...
#
# Compilation INFO:Applying transformation: enableIfEquationRewrite...
#
# Compilation INFO:Applying transformation: aliasEliminationIfSet...
#
# Compilation INFO:Applying transformation: variabilityPropagationIfSet...
#
# Compilation INFO:Applying transformation: aliasEliminationIfSet...
#
# Compilation INFO:Applying transformation: eliminateLinearEquations...
#
# Compilation INFO:Applying transformation: aliasEliminationIfSet...
#
# Compilation INFO:Applying transformation: enableExpandedInStreamRewrite...
#
# Compilation INFO:Applying transformation: evaluateAsserts...
#
# Compilation INFO:Applying transformation: enableSemiLinearRewrite...
#
# Compilation INFO:Applying transformation: eliminateEqualSwitches...
#
# Compilation INFO:Applying transformation: genInitialEquations...
#
# Compilation INFO:Applying transformation: setFDerivativeVariablesPreBLT...
#
# Compilation INFO:Applying transformation: indexReduction...
#
# Compilation INFO:Applying transformation: LateFunctionInliningIfSet...
#
# Compilation INFO:Applying transformation: commonSubexpressionEliminationIfSet...
#
# Compilation INFO:Applying transformation: addFPreVariables...
#
# Compilation INFO:Applying transformation: aliasEliminationIfSet...
#
# Compilation INFO:Applying transformation: eliminateLinearEquations...
#
# Compilation INFO:Applying transformation: sortDependentParameters...
#
# Compilation INFO:Applying transformation: addRuntimeOptionParameters...
#
# Compilation INFO:Applying transformation: computeMatchingsAndBLT...
#
# Compilation INFO:Warning at line 1757, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo':
#
# Compilation INFO:  Iteration variable "chwp_1.filter.x[1]" is missing start value!
#
# Compilation INFO:Warning at line 1757, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo':
#
# Compilation INFO:  Iteration variable "chwp_2.filter.x[1]" is missing start value!
#
# Compilation INFO:Warning at line 1757, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo':
#
# Compilation INFO:  Iteration variable "chwp_3.filter.x[1]" is missing start value!
#
# Compilation INFO:Warning at line 1757, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo':
#
# Compilation INFO:  Iteration variable "chwp_4.filter.x[1]" is missing start value!
#
# Compilation INFO:Generating code...
# Compilation INFO:====== Model compiled successfully =======
#
# Compilation INFO:
#
# Compilation INFO:Compilation_Result_Directory:fmus/nb_hydr_static_v1
#
# Compilation INFO:Compilation script compeltes
# Compilation ERROR:[sudo] password for zhiangz:
# Compilation DEBUG:Original FMU directory: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpcomp_nb_hydr_static_1657202577/fmus/nb_hydr_static_v1
# Compilation DEBUG:Resulting FMU directory: ./nb_hydr_static_res/compilation
# Compilation INFO:Compilaton succeeded, compiled FMU is ready at: ./nb_hydr_static_res/compilation/nb_hydr_static.fmu
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_nb_hydr_static_1657202627
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_nb_hydr_static_1657202627
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_nb_hydr_static_1657202627/nb_hydr_static.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_nb_hydr_static_1657202627 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//nb_hydr_static.fmu -st 0 -ft 3600 -ll DEBUG -r chw_ret_P.p chw_sup_P.p chw_sup_m.m_flow chiller_1.port_a.p chiller_1.port_b.p
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_nb_hydr_static_1657202627
# ./nb_hydr_static_res/compilation/nb_hydr_static.fmu ./nb_hydr_static_res/compilation/nb_hydr_static.mo
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 215
#
# Simulation INFO: Number of function evaluations                  : 249
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 4
#
# Simulation INFO: Number of nonlinear iterations                  : 245
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 216
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-03   1.00000000e-03]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.13920211792 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/nb_hydr_static_v1
#
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation INFO:Simulation script compeltes
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_nb_hydr_static_1657202627/mo_sim_res/nb_hydr_static_v1
# Simulation INFO:Simulation succeeded, results are ready at: ./nb_hydr_static_res/simres_run4

# %%
res_pd
# Out:
#              time  chw_ret_P.p  chiller_1.port_a.p  chiller_1.port_b.p  \
# 0    0.000000e+00     400000.0       391854.674272       391773.780234
# 1    4.112140e-09     400000.0       391854.674272       391773.780234
# 2    4.112552e-05     400000.0       391854.674338       391773.780300
# 3    4.523396e-04     400000.0       391854.682291       391773.788246
# 4    8.635536e-04     400000.0       391854.703496       391773.809433
# ..            ...          ...                 ...                 ...
# 211  9.866507e+02     400000.0       974765.752803       974173.909976
# 212  1.270621e+03     400000.0       974765.752803       974173.909976
# 213  1.554591e+03     400000.0       974765.752803       974173.909976
# 214  2.048474e+03     400000.0       974765.752803       974173.909976
# 215  3.600000e+03     400000.0       974765.752803       974173.909976
#
#        chw_sup_P.p  chw_sup_m.m_flow
# 0    364231.557736        400.722965
# 1    364231.557736        400.722965
# 2    364231.557782        400.722965
# 3    364231.563345        400.722982
# 4    364231.578176        400.723028
# ..             ...               ...
# 211  771868.696302       1086.126945
# 212  771868.696302       1086.126945
# 213  771868.696302       1086.126945
# 214  771868.696302       1086.126945
# 215  771868.696302       1086.126945
#
# [216 rows x 6 columns]

# %%
mo_path = '../../MoModels/secondary_pump_test.mo'#'../../MoModels/nb_hydr_static.mo'
fmu_name = mo_path.split(os.sep)[-1].split('.mo')[0]
res_dir = 'secondary_pump_test_res'#'./nb_hydr_static_res'
sudo_pwd = '63z64q92zza'

# %%
mo_engine = Engine(mo_path, res_dir, sudo_pwd, 
							log_level = 'DEBUG')

sim_res_dir = mo_engine.simulate(start_time=0, final_time=3600,
					res_names = [
								 'pipe_6.m_flow', 'bypass_pipe.m_flow',
                                 'secdy_ret_pipe.m_flow'],
                    set_param_dict = {'chwp18_speed_const.k': 1, 
                                      'chwp1_speed_const.k': 1}
                                )
res_pd = pd.read_csv('{}{}{}_res.csv'.format(sim_res_dir, os.sep, fmu_name))
# Out:
# [2022-07-19 20:08:58,741] ModelicaEngine-secondary_pump_test INFO:Compilation starts
# Compilation INFO:Preparing compilation model directory...
# Compilation DEBUG:Compilation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpcomp_secondary_pump_test_1658232538
# Compilation DEBUG:docker_mo_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpcomp_secondary_pump_test_1658232538/secondary_pump_test.mo
# Compilation DEBUG:docker_mo_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpcomp_secondary_pump_test_1658232538
# Compilation INFO:Calling compilation script...
# Compilation DEBUG:Compilation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh /tmpcomp_secondary_pump_test_1658232538 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/compile_fmu_1.py secondary_pump_test /tmpcomp_secondary_pump_test_1658232538 me False
# Compilation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts//tmpcomp_secondary_pump_test_1658232538
#
# Compilation INFO:Compiler arguments:
#
# Compilation INFO:  -log=info,w|xml|stderr -opt=nle_solver_tol_factor:0.01,generate_html_diagnostics:false -target=me -version=2.0 -platform=linux64 -out=. -modelicapath=/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts//tmpcomp_secondary_pump_test_1658232538:/usr/local/JModelica/ThirdParty/MSL  secondary_pump_test
#
# Compilation INFO:Current working directory:
#
# Compilation INFO:  /mnt/shared/JMDcokerScripts/tmpcomp_secondary_pump_test_1658232538
#
# Compilation INFO:Compiler version: unknown
#
# Compilation INFO:Java version: 11.0.4
#
# Compilation INFO:OS name: Linux
#
# Compilation INFO:OS architecture: amd64
#
# Compilation INFO:MODELICAPATH    = /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts//tmpcomp_secondary_pump_test_1658232538:/usr/local/JModelica/ThirdParty/MSL
#
# Compilation INFO:JAVA_HOME       = /usr/lib/jvm/java-11-openjdk-amd64
#
# Compilation INFO:JMODELICA_HOME  = /usr/local/JModelica/bin/..
#
# Compilation INFO:======= Compiling model =======
#
# Compilation INFO:Checking for errors...
#
# Compilation INFO:MODELICAPATH = /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts//tmpcomp_secondary_pump_test_1658232538:/usr/local/JModelica/ThirdParty/MSL
#
# Compilation INFO:extra_lib_dirs =
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpcomp_secondary_pump_test_1658232538/secondary_pump_test.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/SpeedControlled_y.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Icons.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/PartialFlowMachine.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/LumpedVolumeDeclarations.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/PartialTwoPortInterface.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/PartialTwoPort.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/Boundary_pT.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/BaseClasses/PartialSource_Xi_C.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/BaseClasses/PartialSource.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/Junction.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/PartialThreeWayResistance.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/Pipe.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/BaseClasses/Pipe.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/TwoPortFlowResistanceParameters.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/FixedResistances/PressureDrop.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/PartialResistance.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Sources.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Interfaces.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Icons.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Actuators/package.mo...
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Actuators/Valves/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Actuators/Valves/TwoWayLinear.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Actuators/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Actuators/BaseClasses/PartialTwoWayValveKv.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Actuators/BaseClasses/PartialTwoWayValve.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Actuators/BaseClasses/ValveParameters.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Actuators/BaseClasses/ActuatorSignal.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Math.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/Pumps/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/Pumps/Wilo/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/Pumps/Wilo/CronolineIL80slash220dash4slash4.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/Data/Generic.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Types.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/SIunits.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Types.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Types.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Media/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Media/Water.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Media/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Media/Water/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Routing.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Delays/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Delays/DelayFirstOrder.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/MixingVolume.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/BaseClasses/PartialMixingVolume.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/IdealSource.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/PartialTwoPortTransport.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/PowerInterface.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/MassFlowRate.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/RelativePressure.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/FlowMachineInterface.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Types.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Interfaces.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/flowParameters.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/efficiencyParameters.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/powerParameters.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Constants.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/ModelicaServices/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/flowParametersInternal.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/splineDerivatives.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/isMonotonic.mo...
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Math/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Math/BooleanVectors.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Utilities/package.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Utilities/Streams.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/pressure.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Utilities.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/cubicHermiteLinearExtrapolation.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/power.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/smoothMax.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/regStep.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Movers/BaseClasses/Characteristics/efficiency.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Vessels.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/StaticTwoPortConservationEquation.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Interfaces/ConservationEquation.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/HeatTransfer/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/HeatTransfer/Sources/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/HeatTransfer/Sources/PrescribedTemperature.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Utilities/Strings.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sensors/BaseClasses/PartialFlowSensor.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_dp.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_m_flow.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_dp_der.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_dp_der2.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_m_flow_der.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/BaseClasses/FlowModels/basicFlowFunction_m_flow_der2.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/MixingVolumes/BaseClasses/MixingVolumeHeatPort.mo...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Fluid/Pipes.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/inverseXRegularized.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/package.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/smoothTransition.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/der_smoothTransition.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/der_2_smoothTransition.mo...
#
# Compilation INFO:Parsing /mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Utilities/Math/Functions/BaseClasses/der_inverseXRegularized.mo...
#
# Compilation INFO:Warning at line 26, column 3, in file '/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Actuators/BaseClasses/ValveParameters.mo', UNABLE_TO_INFER_EQUALITY_FOR_DUPLICATES,
#
# Compilation INFO:In components:
#
# Compilation INFO:    chwp_18_val
#
# Compilation INFO:    chwp_1_val
#
# Compilation INFO:  The component m_flow_nominal is declared multiple times and can not be verified to be identical to other declaration(s) with the same name.
#
# Compilation INFO:Warning at line 50, column 12, in file '/mnt/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/Buildings/Fluid/Sources/BaseClasses/PartialSource.mo', DEPRECATED_CARDINALITY,
#
# Compilation INFO:In components:
#
# Compilation INFO:    chw_ret
#
# Compilation INFO:    chw_sup
#
# Compilation INFO:  The cardinality() function-like operator is deprecated, and will be removed in a future version of Modelica
#
# Compilation INFO:Warning at line 1775, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.c0 does not have a binding expression
#
# Compilation INFO:Warning at line 1775, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_18:
#
# Compilation INFO:  The parameter chwp_18.filter.c0 does not have a binding expression
#
# Compilation INFO:Warning at line 1775, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_18_val:
#
# Compilation INFO:  The parameter chwp_18_val.filter.c0 does not have a binding expression
#
# Compilation INFO:Warning at line 1775, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1_val:
#
# Compilation INFO:  The parameter chwp_1_val.filter.c0 does not have a binding expression
#
# Compilation INFO:Warning at line 1776, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.c1 does not have a binding expression
# Compilation INFO:Warning at line 1776, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_18:
#
# Compilation INFO:  The parameter chwp_18.filter.c1 does not have a binding expression
#
# Compilation INFO:Warning at line 1776, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_18_val:
#
# Compilation INFO:  The parameter chwp_18_val.filter.c1 does not have a binding expression
#
# Compilation INFO:Warning at line 1776, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1_val:
#
# Compilation INFO:  The parameter chwp_1_val.filter.c1 does not have a binding expression
#
# Compilation INFO:Warning at line 1780, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.a does not have a binding expression
#
# Compilation INFO:Warning at line 1780, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_18:
#
# Compilation INFO:  The parameter chwp_18.filter.a does not have a binding expression
#
# Compilation INFO:Warning at line 1780, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_18_val:
#
# Compilation INFO:  The parameter chwp_18_val.filter.a does not have a binding expression
#
# Compilation INFO:Warning at line 1780, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1_val:
#
# Compilation INFO:  The parameter chwp_1_val.filter.a does not have a binding expression
#
# Compilation INFO:Warning at line 1781, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.b does not have a binding expression
#
# Compilation INFO:Warning at line 1781, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_18:
#
# Compilation INFO:  The parameter chwp_18.filter.b does not have a binding expression
#
# Compilation INFO:Warning at line 1781, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_18_val:
#
# Compilation INFO:  The parameter chwp_18_val.filter.b does not have a binding expression
#
# Compilation INFO:Warning at line 1781, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1_val:
#
# Compilation INFO:  The parameter chwp_1_val.filter.b does not have a binding expression
#
# Compilation INFO:Warning at line 1782, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.ku does not have a binding expression
#
# Compilation INFO:Warning at line 1782, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_18:
#
# Compilation INFO:  The parameter chwp_18.filter.ku does not have a binding expression
#
# Compilation INFO:Warning at line 1782, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_18_val:
#
# Compilation INFO:  The parameter chwp_18_val.filter.ku does not have a binding expression
#
# Compilation INFO:Warning at line 1782, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1_val:
#
# Compilation INFO:  The parameter chwp_1_val.filter.ku does not have a binding expression
#
# Compilation INFO:Warning at line 1783, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.k1 does not have a binding expression
#
# Compilation INFO:Warning at line 1783, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_18:
#
# Compilation INFO:  The parameter chwp_18.filter.k1 does not have a binding expression
#
# Compilation INFO:Warning at line 1783, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_18_val:
#
# Compilation INFO:  The parameter chwp_18_val.filter.k1 does not have a binding expression
#
# Compilation INFO:Warning at line 1783, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1_val:
#
# Compilation INFO:  The parameter chwp_1_val.filter.k1 does not have a binding expression
#
# Compilation INFO:Warning at line 1785, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1:
#
# Compilation INFO:  The parameter chwp_1.filter.k2 does not have a binding expression
#
# Compilation INFO:Warning at line 1785, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_18:
#
# Compilation INFO:  The parameter chwp_18.filter.k2 does not have a binding expression
#
# Compilation INFO:Warning at line 1785, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_18_val:
#
# Compilation INFO:  The parameter chwp_18_val.filter.k2 does not have a binding expression
#
# Compilation INFO:Warning at line 1785, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo', PARAMETER_MISSING_BINDING_EXPRESSION,
#
# Compilation INFO:In component chwp_1_val:
#
# Compilation INFO:  The parameter chwp_1_val.filter.k2 does not have a binding expression
#
# Compilation INFO:Flattening model...
#
# Compilation INFO:Parsing /usr/local/JModelica/ThirdParty/MSL/Modelica/Utilities/Types.mo...
#
# Compilation INFO:Applying transformation: enableIfEquationElimination...
#
# Compilation INFO:Applying transformation: genInitArrayStatements...
#
# Compilation INFO:Applying transformation: scalarize...
#
# Compilation INFO:Applying transformation: MakeReinitedVarsStates...
#
# Compilation INFO:Applying transformation: enableIfEquationElimination...
#
# Compilation INFO:Applying transformation: enableStreamsRewrite...
#
# Compilation INFO:Applying transformation: ExtractEventGeneratingExpressions...
#
# Compilation INFO:Applying transformation: GenerateEventIndicators...
#
# Compilation INFO:Applying transformation: convertWhenToIf...
#
# Compilation INFO:Applying transformation: FunctionInliningIfSet...
#
# Compilation INFO:Applying transformation: setFDerivativeVariables...
#
# Compilation INFO:Applying transformation: addFPreVariables...
#
# Compilation INFO:Applying transformation: enableIfEquationRewrite...
#
# Compilation INFO:Applying transformation: aliasEliminationIfSet...
#
# Compilation INFO:Applying transformation: variabilityPropagationIfSet...
#
# Compilation INFO:Applying transformation: aliasEliminationIfSet...
#
# Compilation INFO:Applying transformation: eliminateLinearEquations...
#
# Compilation INFO:Applying transformation: aliasEliminationIfSet...
#
# Compilation INFO:Applying transformation: enableExpandedInStreamRewrite...
# Compilation INFO:Applying transformation: evaluateAsserts...
#
# Compilation INFO:Applying transformation: enableSemiLinearRewrite...
#
# Compilation INFO:Applying transformation: eliminateEqualSwitches...
#
# Compilation INFO:Applying transformation: genInitialEquations...
#
# Compilation INFO:Applying transformation: setFDerivativeVariablesPreBLT...
#
# Compilation INFO:Applying transformation: indexReduction...
#
# Compilation INFO:Applying transformation: LateFunctionInliningIfSet...
#
# Compilation INFO:Applying transformation: commonSubexpressionEliminationIfSet...
#
# Compilation INFO:Applying transformation: addFPreVariables...
#
# Compilation INFO:Applying transformation: aliasEliminationIfSet...
#
# Compilation INFO:Applying transformation: eliminateLinearEquations...
#
# Compilation INFO:Applying transformation: sortDependentParameters...
#
# Compilation INFO:Applying transformation: addRuntimeOptionParameters...
#
# Compilation INFO:Applying transformation: computeMatchingsAndBLT...
#
# Compilation INFO:Warning at line 1757, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo':
#
# Compilation INFO:  Iteration variable "chwp_1.filter.x[1]" is missing start value!
#
# Compilation INFO:Warning at line 1757, column 5, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Blocks/Continuous.mo':
#
# Compilation INFO:  Iteration variable "chwp_18.filter.x[1]" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "bypass_pipe.conPipWal[10].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "bypass_pipe.conPipWal[2].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "bypass_pipe.conPipWal[3].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "bypass_pipe.conPipWal[4].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "bypass_pipe.conPipWal[5].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "bypass_pipe.conPipWal[6].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "bypass_pipe.conPipWal[7].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "bypass_pipe.conPipWal[8].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "bypass_pipe.conPipWal[9].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "chiller_1.conPipWal[10].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "chiller_1.conPipWal[2].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "chiller_1.conPipWal[3].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "chiller_1.conPipWal[4].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "chiller_1.conPipWal[5].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "chiller_1.conPipWal[6].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "chiller_1.conPipWal[7].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "chiller_1.conPipWal[8].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "chiller_1.conPipWal[9].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_10.conPipWal[10].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_10.conPipWal[2].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_10.conPipWal[3].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_10.conPipWal[4].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_10.conPipWal[5].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_10.conPipWal[6].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_10.conPipWal[7].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_10.conPipWal[8].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_10.conPipWal[9].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_13.conPipWal[10].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_13.conPipWal[2].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_13.conPipWal[3].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
# Compilation INFO:  Iteration variable "pipe_13.conPipWal[4].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_13.conPipWal[5].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_13.conPipWal[6].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_13.conPipWal[7].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_13.conPipWal[8].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_13.conPipWal[9].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_6.conPipWal[10].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_6.conPipWal[2].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_6.conPipWal[3].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_6.conPipWal[4].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_6.conPipWal[5].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_6.conPipWal[6].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_6.conPipWal[7].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_6.conPipWal[8].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_6.conPipWal[9].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_8.conPipWal[10].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_8.conPipWal[2].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_8.conPipWal[3].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_8.conPipWal[4].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_8.conPipWal[5].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_8.conPipWal[6].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_8.conPipWal[7].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_8.conPipWal[8].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_8.conPipWal[9].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_9.conPipWal[10].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_9.conPipWal[2].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_9.conPipWal[3].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_9.conPipWal[4].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_9.conPipWal[5].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_9.conPipWal[6].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_9.conPipWal[7].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_9.conPipWal[8].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_9.conPipWal[9].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "secdy_ret_pipe.conPipWal[10].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "secdy_ret_pipe.conPipWal[2].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "secdy_ret_pipe.conPipWal[3].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "secdy_ret_pipe.conPipWal[4].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
# Compilation INFO:  Iteration variable "secdy_ret_pipe.conPipWal[5].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "secdy_ret_pipe.conPipWal[6].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "secdy_ret_pipe.conPipWal[7].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "secdy_ret_pipe.conPipWal[8].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2864, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "secdy_ret_pipe.conPipWal[9].Q_flow" is missing start value!
#
# Compilation INFO:Warning at line 2866, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "bypass_pipe.conPipWal[1].dT" is missing start value!
#
# Compilation INFO:Warning at line 2866, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "chiller_1.conPipWal[1].dT" is missing start value!
#
# Compilation INFO:Warning at line 2866, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_10.conPipWal[1].dT" is missing start value!
#
# Compilation INFO:Warning at line 2866, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_13.conPipWal[1].dT" is missing start value!
#
# Compilation INFO:Warning at line 2866, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_6.conPipWal[1].dT" is missing start value!
#
# Compilation INFO:Warning at line 2866, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_8.conPipWal[1].dT" is missing start value!
#
# Compilation INFO:Warning at line 2866, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "pipe_9.conPipWal[1].dT" is missing start value!
#
# Compilation INFO:Warning at line 2866, column 7, in file '/usr/local/JModelica/ThirdParty/MSL/Modelica/Thermal/HeatTransfer.mo':
#
# Compilation INFO:  Iteration variable "secdy_ret_pipe.conPipWal[1].dT" is missing start value!
#
# Compilation INFO:Generating code...
#
# Compilation INFO:====== Model compiled successfully =======
#
# Compilation INFO:
#
# Compilation INFO:Compilation_Result_Directory:fmus/secondary_pump_test_v1
#
# Compilation INFO:Compilation script compeltes
# Compilation ERROR:[sudo] password for zhiangz:
# Compilation DEBUG:Original FMU directory: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpcomp_secondary_pump_test_1658232538/fmus/secondary_pump_test_v1
# Compilation DEBUG:Resulting FMU directory: secondary_pump_test_res/compilation
# Compilation INFO:Compilaton succeeded, compiled FMU is ready at: secondary_pump_test_res/compilation/secondary_pump_test.fmu
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658232586
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658232586
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658232586/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658232586 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:1 chwp1_speed_const.k:1
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658232586
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 190
#
# Simulation INFO: Number of function evaluations                  : 234
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 5
#
# Simulation INFO: Number of nonlinear iterations                  : 230
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 191
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.123733043671 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658232586/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run1

# %%
res_pd
# Out:
#              time  pipe_6.m_flow  bypass_pipe.m_flow  secdy_ret_pipe.m_flow
# 0    0.000000e+00   0.000000e+00        0.000000e+00          -0.000000e+00
# 1    4.112140e-09   0.000000e+00        0.000000e+00          -0.000000e+00
# 2    4.112552e-05   2.208036e-07        6.445726e-07          -2.208036e-07
# 3    4.523396e-04   2.670885e-05        7.796893e-05          -2.670885e-05
# 4    8.635536e-04   9.733361e-05        2.841379e-04          -9.733361e-05
# ..            ...            ...                 ...                    ...
# 186  2.220432e+03   2.549799e+02        2.428772e+02          -2.549799e+02
# 187  2.649174e+03   2.549799e+02        2.428772e+02          -2.549799e+02
# 188  3.077916e+03   2.549799e+02        2.428772e+02          -2.549799e+02
# 189  3.506658e+03   2.549799e+02        2.428772e+02          -2.549799e+02
# 190  3.600000e+03   2.549799e+02        2.428772e+02          -2.549799e+02
#
# [191 rows x 4 columns]

# %%
first_m = []
second_m = []
for i in range(1, 11):
    secondary_speed = i/10
    sim_res_dir = mo_engine.simulate(start_time=0, final_time=3600,
					res_names = [
								 'pipe_6.m_flow', 'pipe_10.m_flow', 'bypass_pipe.m_flow',
                                 'secdy_ret_pipe.m_flow'],
                    set_param_dict = {'chwp18_speed_const.k': secondary_speed, 
                                      'chwp1_speed_const.k': 1}
                                )
    res_pd = pd.read_csv('{}{}{}_res.csv'.format(sim_res_dir, os.sep, fmu_name))
    first_m_i = res_pd['pipe_10.m_flow'].iloc[-1]
    second_m_i = res_pd['pipe_6.m_flow'].iloc[-1]
    first_m.append(first_m_i)
    second_m.append(second_m_i)
# Out:
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233695
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233695
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233695/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233695 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:0.1 chwp1_speed_const.k:1
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233695
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 179
#
# Simulation INFO: Number of function evaluations                  : 219
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 4
#
# Simulation INFO: Number of nonlinear iterations                  : 215
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 180
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.105242013931 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233695/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run24
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233698
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233698
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233698/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233698 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:0.2 chwp1_speed_const.k:1
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233698
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 184
#
# Simulation INFO: Number of function evaluations                  : 227
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 6
#
# Simulation INFO: Number of nonlinear iterations                  : 223
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 185
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.0963039398193 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233698/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run25
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233701
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233701
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233701/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233701 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:0.3 chwp1_speed_const.k:1
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233701
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 180
#
# Simulation INFO: Number of function evaluations                  : 221
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 5
#
# Simulation INFO: Number of nonlinear iterations                  : 217
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 181
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.0916669368744 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233701/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run26
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233704
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233704
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233704/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233704 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:0.4 chwp1_speed_const.k:1
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233704
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 181
#
# Simulation INFO: Number of function evaluations                  : 213
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 3
#
# Simulation INFO: Number of nonlinear iterations                  : 209
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 182
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.0879099369049 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation INFO:Simulation script compeltes
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233704/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run27
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233706
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233706
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233706/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233706 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:0.5 chwp1_speed_const.k:1
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233706
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 173
#
# Simulation INFO: Number of function evaluations                  : 207
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 3
#
# Simulation INFO: Number of nonlinear iterations                  : 203
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 174
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.101957082748 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233706/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run28
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233709
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233709
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233709/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233709 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:0.6 chwp1_speed_const.k:1
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233709
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 181
#
# Simulation INFO: Number of function evaluations                  : 224
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 5
#
# Simulation INFO: Number of nonlinear iterations                  : 220
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 182
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.0933530330658 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233709/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run29
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233711
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233711
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233711/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233711 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:0.7 chwp1_speed_const.k:1
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233711
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 188
#
# Simulation INFO: Number of function evaluations                  : 237
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 7
#
# Simulation INFO: Number of nonlinear iterations                  : 233
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 189
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.1226811409 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233711/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run30
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233714
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233714
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233714/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233714 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:0.8 chwp1_speed_const.k:1
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233714
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
# Simulation INFO: Number of steps                                 : 195
#
# Simulation INFO: Number of function evaluations                  : 244
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 7
#
# Simulation INFO: Number of nonlinear iterations                  : 240
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 196
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.103145122528 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233714/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run31
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233717
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233717
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233717/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233717 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:0.9 chwp1_speed_const.k:1
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233717
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 182
#
# Simulation INFO: Number of function evaluations                  : 225
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 5
#
# Simulation INFO: Number of nonlinear iterations                  : 221
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 183
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.138278007507 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233717/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run32
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233720
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233720
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233720/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233720 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:1.0 chwp1_speed_const.k:1
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233720
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 190
#
# Simulation INFO: Number of function evaluations                  : 234
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 5
#
# Simulation INFO: Number of nonlinear iterations                  : 230
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 191
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.128713130951 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation INFO:Simulation script compeltes
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233720/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run33

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(first_m, color = 'k', label = 'first')
plt.plot(second_m, color = 'b', label = 'second')
plt.title('first fixed at 1, second speed changing')
plt.legend()

# %%
first_m = []
second_m = []
for i in range(1, 11):
    secondary_speed = i/10
    sim_res_dir = mo_engine.simulate(start_time=0, final_time=3600,
					res_names = [
								 'pipe_6.m_flow', 'pipe_10.m_flow', 'bypass_pipe.m_flow',
                                 'secdy_ret_pipe.m_flow'],
                    set_param_dict = {'chwp18_speed_const.k': secondary_speed, 
                                      'chwp1_speed_const.k': secondary_speed}
                                )
    res_pd = pd.read_csv('{}{}{}_res.csv'.format(sim_res_dir, os.sep, fmu_name))
    first_m_i = res_pd['pipe_10.m_flow'].iloc[-1]
    second_m_i = res_pd['pipe_6.m_flow'].iloc[-1]
    first_m.append(first_m_i)
    second_m.append(second_m_i)
# Out:
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233745
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233745
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233745/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233745 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:0.1 chwp1_speed_const.k:0.1
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233745
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 131
#
# Simulation INFO: Number of function evaluations                  : 156
#
# Simulation INFO: Number of Jacobian evaluations                  : 3
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 1
#
# Simulation INFO: Number of nonlinear iterations                  : 152
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 132
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.182615995407 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233745/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run34
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233752
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233752
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233752/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233752 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:0.2 chwp1_speed_const.k:0.2
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233752
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 153
#
# Simulation INFO: Number of function evaluations                  : 190
#
# Simulation INFO: Number of Jacobian evaluations                  : 3
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 4
#
# Simulation INFO: Number of nonlinear iterations                  : 186
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 154
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.122077941895 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233752/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run35
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233759
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233759
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233759/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233759 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:0.3 chwp1_speed_const.k:0.3
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233759
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 157
#
# Simulation INFO: Number of function evaluations                  : 192
# Simulation INFO: Number of Jacobian evaluations                  : 3
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 3
#
# Simulation INFO: Number of nonlinear iterations                  : 188
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 158
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.305195093155 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233759/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run36
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233765
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233765
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233765/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233765 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:0.4 chwp1_speed_const.k:0.4
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233765
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 168
#
# Simulation INFO: Number of function evaluations                  : 199
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 3
#
# Simulation INFO: Number of nonlinear iterations                  : 195
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 169
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.181991100311 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation INFO:Simulation script compeltes
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233765/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run37
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233770
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233770
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233770/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233770 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:0.5 chwp1_speed_const.k:0.5
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233770
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 171
#
# Simulation INFO: Number of function evaluations                  : 198
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 1
#
# Simulation INFO: Number of nonlinear iterations                  : 194
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 172
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.199265956879 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation INFO:Simulation script compeltes
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233770/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run38
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233774
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233774
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233774/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233774 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:0.6 chwp1_speed_const.k:0.6
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233774
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 174
#
# Simulation INFO: Number of function evaluations                  : 210
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 4
#
# Simulation INFO: Number of nonlinear iterations                  : 206
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 175
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.167106151581 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233774/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run39
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233779
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233779
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233779/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233779 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:0.7 chwp1_speed_const.k:0.7
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233779
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 172
#
# Simulation INFO: Number of function evaluations                  : 209
#
# Simulation INFO: Number of Jacobian evaluations                  : 3
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 3
#
# Simulation INFO: Number of nonlinear iterations                  : 205
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 173
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.160779953003 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233779/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run40
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233783
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233783
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233783/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233783 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:0.8 chwp1_speed_const.k:0.8
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233783
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
# Simulation INFO: Number of steps                                 : 174
#
# Simulation INFO: Number of function evaluations                  : 216
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 5
#
# Simulation INFO: Number of nonlinear iterations                  : 212
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 175
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.196281909943 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233783/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run41
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233788
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233788
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233788/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233788 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:0.9 chwp1_speed_const.k:0.9
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233788
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 187
#
# Simulation INFO: Number of function evaluations                  : 233
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 5
#
# Simulation INFO: Number of nonlinear iterations                  : 229
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 188
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.185771942139 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233788/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run42
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233792
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233792
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233792/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233792 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:1.0 chwp1_speed_const.k:1.0
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233792
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 190
#
# Simulation INFO: Number of function evaluations                  : 234
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 5
#
# Simulation INFO: Number of nonlinear iterations                  : 230
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 191
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.185807943344 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233792/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run43

# %%
plt.plot(first_m, color = 'k', label = 'first')
plt.plot(second_m, color = 'b', label = 'second')
plt.title('first and second speed changing')
plt.legend()

# %%
first_m = []
second_m = []
for i in range(1, 11):
    first_speed = i/10
    sim_res_dir = mo_engine.simulate(start_time=0, final_time=3600,
					res_names = [
								 'pipe_6.m_flow', 'pipe_10.m_flow', 'bypass_pipe.m_flow',
                                 'secdy_ret_pipe.m_flow'],
                    set_param_dict = {'chwp18_speed_const.k': 1, 
                                      'chwp1_speed_const.k': first_speed}
                                )
    res_pd = pd.read_csv('{}{}{}_res.csv'.format(sim_res_dir, os.sep, fmu_name))
    first_m_i = res_pd['pipe_10.m_flow'].iloc[-1]
    second_m_i = res_pd['pipe_6.m_flow'].iloc[-1]
    first_m.append(first_m_i)
    second_m.append(second_m_i)
plt.plot(first_m, color = 'k', label = 'first')
plt.plot(second_m, color = 'b', label = 'second')
plt.title('second fixed at 1, first speed changing')
plt.legend()
# Out:
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233836
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233836
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233836/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233836 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:1 chwp1_speed_const.k:0.1
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233836
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 169
#
# Simulation INFO: Number of function evaluations                  : 207
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 4
#
# Simulation INFO: Number of nonlinear iterations                  : 203
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 170
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.181934833527 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation INFO:Simulation script compeltes
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233836/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run44
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233841
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233841
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233841/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233841 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:1 chwp1_speed_const.k:0.2
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233841
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 173
#
# Simulation INFO: Number of function evaluations                  : 212
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 5
#
# Simulation INFO: Number of nonlinear iterations                  : 208
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 174
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.14043211937 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation INFO:Simulation script compeltes
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233841/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run45
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233846
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233846
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233846/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233846 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:1 chwp1_speed_const.k:0.3
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233846
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 169
#
# Simulation INFO: Number of function evaluations                  : 210
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 6
#
# Simulation INFO: Number of nonlinear iterations                  : 206
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 170
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.141202926636 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation INFO:Simulation script compeltes
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233846/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run46
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233850
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233850
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233850/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233850 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:1 chwp1_speed_const.k:0.4
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233850
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 169
#
# Simulation INFO: Number of function evaluations                  : 203
#
# Simulation INFO: Number of Jacobian evaluations                  : 3
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 4
#
# Simulation INFO: Number of nonlinear iterations                  : 199
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 170
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.143241882324 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233850/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run47
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233854
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233854
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233854/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233854 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:1 chwp1_speed_const.k:0.5
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233854
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 161
#
# Simulation INFO: Number of function evaluations                  : 192
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 3
#
# Simulation INFO: Number of nonlinear iterations                  : 188
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 162
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.155763149261 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233854/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run48
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233858
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233858
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233858/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233858 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:1 chwp1_speed_const.k:0.6
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233858
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 178
#
# Simulation INFO: Number of function evaluations                  : 221
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 5
#
# Simulation INFO: Number of nonlinear iterations                  : 217
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 179
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.159870862961 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation INFO:Simulation script compeltes
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233858/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run49
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233862
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233862
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233862/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233862 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:1 chwp1_speed_const.k:0.7
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233862
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 178
#
# Simulation INFO: Number of function evaluations                  : 222
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 6
#
# Simulation INFO: Number of nonlinear iterations                  : 218
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 179
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.171318054199 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233862/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run50
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233866
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233866
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233866/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233866 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:1 chwp1_speed_const.k:0.8
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233866
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
# Simulation INFO: Number of steps                                 : 184
#
# Simulation INFO: Number of function evaluations                  : 222
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 4
#
# Simulation INFO: Number of nonlinear iterations                  : 218
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 185
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.299623966217 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation INFO:Simulation script compeltes
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233866/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run51
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233872
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233872
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233872/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233872 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:1 chwp1_speed_const.k:0.9
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233872
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 183
#
# Simulation INFO: Number of function evaluations                  : 226
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 5
#
# Simulation INFO: Number of nonlinear iterations                  : 222
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 184
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.304647922516 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation INFO:Simulation script compeltes
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233872/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run52
# Simulation INFO:Preparing simulation model directory...
# Simulation DEBUG:Simulation model temporary directory is:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233878
# Simulation DEBUG:fmu_in_docker_dir:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233878
# Simulation DEBUG:fmu_in_docker_path:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233878/secondary_pump_test.fmu
# Simulation INFO:Calling simulation script...
# Simulation DEBUG:Simulation script is: echo 63z64q92zza | sudo -S /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/jm_ipython.sh .//tmpsimu_secondary_pump_test_1658233878 /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/run_fmu_1.py -p .//secondary_pump_test.fmu -st 0 -ft 3600 -ll DEBUG -r pipe_6.m_flow pipe_10.m_flow bypass_pipe.m_flow secdy_ret_pipe.m_flow -s chwp18_speed_const.k:1 chwp1_speed_const.k:1.0
# Simulation INFO:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts:/home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/.//tmpsimu_secondary_pump_test_1658233878
#
# Simulation INFO:Final Run Statistics: ---
#
# Simulation INFO:
#
# Simulation INFO: Number of steps                                 : 190
#
# Simulation INFO: Number of function evaluations                  : 234
#
# Simulation INFO: Number of Jacobian evaluations                  : 4
#
# Simulation INFO: Number of function eval. due to Jacobian eval.  : 0
#
# Simulation INFO: Number of error test failures                   : 5
#
# Simulation INFO: Number of nonlinear iterations                  : 230
#
# Simulation INFO: Number of nonlinear convergence failures        : 0
#
# Simulation INFO: Number of state function evaluations            : 191
#
# Simulation INFO:
#
# Simulation INFO:Solver options:
#
# Simulation INFO:
#
# Simulation INFO: Solver                   : CVode
#
# Simulation INFO: Linear multistep method  : BDF
#
# Simulation INFO: Nonlinear solver         : Newton
#
# Simulation INFO: Linear solver type       : DENSE
#
# Simulation INFO: Maximal order            : 5
#
# Simulation INFO: Tolerances (absolute)    : [  1.00000000e-08   1.00000000e-08   1.00000000e-08   1.00000000e-08
#
# Simulation INFO:   1.00000000e-03   1.00000000e-08   1.00000000e-03   1.00000000e-03
#
# Simulation INFO:   1.00000000e-08   1.00000000e-03   1.00000000e-08   1.00000000e-08]
#
# Simulation INFO: Tolerances (relative)    : 1e-08
#
# Simulation INFO:
#
# Simulation INFO:Simulation interval    : 0.0 - 3600.0 seconds.
#
# Simulation INFO:Elapsed simulation time: 0.282674074173 seconds.
#
# Simulation INFO:Simulation_Result_Directory:mo_sim_res/secondary_pump_test_v1
#
# Simulation ERROR:[sudo] password for zhiangz:
# Simulation INFO:Simulation script compeltes
# Simulation DEBUG:Original results path: /home/zhiangz/Hybrid-Modeling/GreyBoxCalibration/ModelicaEngine/ModelicaEngine/JMDcokerScripts/tmpsimu_secondary_pump_test_1658233878/mo_sim_res/secondary_pump_test_v1
# Simulation INFO:Simulation succeeded, results are ready at: secondary_pump_test_res/simres_run53

# %%
first_m = []
second_m = []
second_dp = []
for i in range(1, 11):
    secondary_speed = i/10
    sim_res_dir = mo_engine.simulate(start_time=0, final_time=3600,
					res_names = [
								 'pipe_6.m_flow', 'pipe_10.m_flow', 'bypass_pipe.m_flow',
                                 'secdy_ret_pipe.m_flow', 'terminal_resist.port_a.p',
                                    'terminal_resist.port_b.p'],
                    set_param_dict = {'chwp18_speed_const.k': secondary_speed, 
                                      'chwp1_speed_const.k': 1}
                                )
    res_pd = pd.read_csv('{}{}{}_res.csv'.format(sim_res_dir, os.sep, fmu_name))
    first_m_i = res_pd['pipe_10.m_flow'].iloc[-1]
    second_m_i = res_pd['pipe_6.m_flow'].iloc[-1]
    first_m.append(first_m_i)
    second_m.append(second_m_i)
